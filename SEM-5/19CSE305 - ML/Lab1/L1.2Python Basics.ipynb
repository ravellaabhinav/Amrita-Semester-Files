# %% [markdown]
# Programming Languages used for Machine Learning:
#
#
# 1.   Python - General purpose (web development) , availability of libraries, Easy to understand
# 2.   R - Statistical based

# %% [markdown]
# Why learn Python for Machine Learning?
#
# Here are some reasons which go in favour of learning Python: * Open Source – free to install * Awesome online community * Very easy to learn * Can become a common language for data science and production of web based analytics products.
#
# Needless to say, it still has few drawbacks too: It is an interpreted language rather than compiled language – hence might take up more CPU time. However, given the savings in programmer time (due to ease of learning), it might still be a good choice.

# %% [markdown]
# #print function
# Note: # to make section

# %%
print("Machine Learning")
# Out:
# Machine Learning

# %%
print('Machine Learning')
# Out:
# Machine Learning

# %% [markdown]
# Join 2 text

# %%
print("Machine Learning" + " Projects")
# Out:
# Machine Learning Projects

# %%
print(8)
# Out:
# 8

# %%
print(8+3)
# Out:
# 11

# %% [markdown]
# #Basic Data types:
#
#
# 1.   int
# 2.   float
# 3.   str

# %%
type(8)
# Out:
# int

# %%
type(5.3)
# Out:
# float

# %%
type("english")
# Out:
# str

# %% [markdown]
# #Variables

# %%
marvel_super_hero = "Iron Man"
print(marvel_super_hero)
# Out:
# Iron Man

# %%
marvel_super_hero = "Captain America"
print(marvel_super_hero)
# Out:
# Captain America

# %%
hero1 , hero2 , hero3 = "Iron Man" , "Captain America" , "Bat Man"
print(hero1)
print(hero2)
print(hero3)
# Out:
# Iron Man
# Captain America
# Bat Man

# %%
x = y = z = 23
print(x)
print(y)
print(z)
# Out:
# 23
# 23
# 23

# %% [markdown]
# # input Function

# %% [markdown]
# input() assumes the value read as a string

# %%
number_1 = input("Enter the first number : ")
number_2 = input("Enter the second number : ")

sum = number_1 + number_2
print(sum)
# Out:
# Enter the first number : 23
# Enter the second number : 23
# 2323

# %%
number_1 = int(input("Enter the first number : "))
number_2 = int(input("Enter the second number : "))

sum = number_1 + number_2
print(sum)
# Out:
# Enter the first number : 23
# Enter the second number : 23
# 46

# %%
# changing the data type in python:
num = 5
print(float(num))
# Out:
# 5.0
